# %% [markdown]
# <span style="background-color: #09C8C1; color: #07199C; font-size:56px"> Apresentação de Vazão</span>

# %% [markdown]
# ## Definição Conceitual:
#
# ### "A vazão é uma grandeza física utilizada para medir a quantidade de fluido que passa por uma determinada seção de um sistema em um intervalo de tempo."
# ### Essa quantidade podendo ser descrita tanto pelo volume quanto pela massa do fluido, que por sua vez pode ser tanto um líquido quanto um gaz.
# ### A vazão volumétrica também pode ser obtida pelo resultado do produto da área seccional pela média da velocidade do fluido.

# %% [markdown]
# ## Definição Matemática:
# ### para vazão volumétrica: $\large Q_v = \frac{V}{t}$ ou   $ \large Q_v = S \cdot v$
#
# #### Onde:
# $\large Q_v$ <span style="font-size:22px">= Vazão volumétrica</span> \
# <span style="font-size:22px">V = volume</span> \
# <span style="font-size:22px">t = tempo</span> \
# <span style="font-size:22px">S = área</span> \
# <span style="font-size:22px">v = velocidade</span>
#
# ### para vazão mássica: $Q_m = \frac{m}{t}$  ou $  Q_m = Q_v \cdot \rho$
# #### Onde:
# $\large Q_m$ <span style="font-size:22px">= Vazão mássica</span> \
# <span style="font-size:22px">m = massa></span> \
# <span style="font-size:22px">t = tempo</span> \
# $\rho$ <span style="font-size:22px">= massa específica</span>

# %% [markdown]
# ## Unidades de Medida (SI):
# ### para vazão volumétrica: $\large\frac{m^3}{s}$
# ### para vazão mássica: $\large\frac{Kg}{s}$

# %% [markdown]
# ### Outras uniades:
# <span style="font-size:20px">**Para volumétrica:**\
# **m³/h** (metros cúbicos por hora)\
# **l/min ou l/h** (litros por minuto ou por hora)\
# **Nm³/h** (normal metro cúbico por hora, usado para gases em condições normais de temperatura e pressão)\
# **SCFH** (_standard cubic feet per hour_ ou pés cubicos por hora padrão, usado em gases)
#
# **Obs: (condições normais ou padrão se refere a 0 °C ou 273,15 K de tempeatura e 1 bar ou 100.000 Pa de Pressão)**
#
# <span style="font-size:20px">**Para mássica:**\
# **kg/h** (quilogramas por hora)\
# **t/h** (toneladas por hora)\
# **lb/h** (libras por hora)</span>

# %% [markdown]
# ## Anedota Histórica
# #### Os relógios de água egípcios, conhecidos como clepsidras, são um dos primeiros instrumentos mecânicos de medição do tempo da humanidade, datando de cerca de 1500 a.C. Eles permitiam medir o tempo à noite, quando os relógios de sol não funcionavam, e usavam o conceito da vazão.
# <img src="relogio_dagua.png" alt="Tela do instalador Python no Windows" width="250" style="display: block; margin: 0 auto;">
#
# ###### Imagem1: relóio de águga egípcio Disponível em: https://www.facebook.com/GamerTche/posts/o-rel%C3%B3gio-de-%C3%A1gua-tamb%C3%A9m-conhecido-como-clepsidra-%C3%A9-um-dos-instrumentos-mais-ant/1142626337866853/

# %% [markdown]
# #### Em 3000 a.C., egípcios criaram os "nilômetros", que eram colunas graduadas nas margens do rio para medir a altura da água. Com isso, conseguiam estimar o volume disponível para irrigação. Povos sumérios também monitoravam rios e canais para garantir uma distribuição justa de água.
# <img src="nilometro_ilustracao.jpg" alt="Tela do instalador Python no Windows" width="500" style="display: block; margin: 0 auto;">
#
# ###### Imagem2: nilômetro Disponível em: https://aventurasnahistoria.com.br/noticias/almanaque/nilometro-invencao-egipcia-usada-para-prever-enchentes-e-determinar-impostos.phtml

# %% [markdown]
# #### Aquedutos Romanos: O governador e engenheiro romano Sexto Júlio Frontino (40–130 d.C.) foi pioneiro no gerenciamento e distribuição urbana de água. Os romanos mediam a vazão pelo tempo que levava para uma quantidade de água encher um reservatório de volume conhecido (vazão por tempo).
# <img src="aqueduto_romano.jpg" alt="Tela do instalador Python no Windows" width="500" style="display: block; margin: 0 auto;">
#
# ###### Imagem3: aqueduto romano Disponível em: https://depositphotos.com/br/vector/roman-aqueduct-ancient-nemausus-southern-france-emperor-antoninus-pius-vintage-218070952.html

# %% [markdown]
# ## Conceitos Físicos Básicos para Medição de Vazão
# ### **Viscosidade**
# <span style="font-size:22px">A viscosidade é a resistência interna de um fluido ao escoamento. Ela representa o "atrito" entre as moléculas do líquido enquanto ele se move. Quanto maior a viscosidade, mais "grosso" é o líquido e mais difícil é fazê-lo escorrer (ex: mel vs. água).</span>
#
# #### Os pontos fundamentais sobre a viscosidade dos líquidos incluem:
#
# <span style="font-size:22px">Viscosidade Dinâmica (μ): Mede a força necessária para mover uma camada de fluido em relação a outra. No Sistema Internacional, é medida em Pascal-segundo (Pa ⋅ s) ou Poise (P).</span>
#
# <span style="font-size:22px">Viscosidade Cinemática (ν): É a razão entre a viscosidade dinâmica e a densidade do líquido</span> $\LARGE \nu = \frac{\mu}{\rho}$.<span style="font-size:22px"> Mede a resistência ao escoamento sob a influência da gravidade.</span>
# ### **Continuidade**
# <span style="font-size:22px">A Equação da Continuidade é o princípio da mecânica dos fluidos que representa a conservação da massa em um escoamento</span>
#
# $\large A_1v_1 = A_2v_2$
#
# ### **Regime de Escoamento**
# #### **Regime laminar:**
# <span style="font-size:22px">O regime laminar é o tipo de escoamento onde o líquido flui em camadas ou lâminas paralelas, de forma suave e ordenada, sem que haja mistura entre elas. É comum em fluidos muito viscosos ou em velocidades muito baixas.</span>
# <img src="regime_laminar.png" alt="Tela do instalador Python no Windows" width="500" style="display: block; margin: 0 auto;">
# #### **Regime turbulento:**
# <span style="font-size:22px">O regime turbulento é o tipo de escoamento onde o líquido se move de forma desordenada e caótica, com as partículas formando redemoinhos (vórtices) e se cruzando. Ocorre em altas velocidades e é dominado por forças inerciais, resultando em uma mistura intensa dentro do fluido.</span>
# <img src="regime_turbulento.png" alt="Tela do instalador Python no Windows" width="500" style="display: block; margin: 0 auto;">
# #### **número de reynolds:**
# <span style="font-size:22px">Número de Reynolds (Re) é um parâmetro adimensional usado na mecânica dos fluidos para prever o padrão de escoamento (se o fluido se move de forma organizada ou caótica). Ele é calculado pela razão entre as forças de inércia e as forças viscosas atuantes no fluido.</span>
#
# ### $ Re = \frac{\rho V L}{\mu}$
#
# #### Onde:
# <span style="font-size:22px">ρ: Densidade do fluido (kg/m³)\
# v: Velocidade média do escoamento (m/s)\
# D: Diâmetro interno do tubo (m)\
# μ: Viscosidade dinâmica do </span> $\large Pa ⋅ s$ <span style="font-size:22px"> ou</span> $\LARGE \frac{kg} {m \cdot s}$
#
# #### Alternativamente, utilizando a viscosidade cinemática $\nu = \frac{\mu}{\rho}$:
#
# <img src="tabel.1.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">
#
#
# ### **Perda de Carga**
#
# <span style="font-size:22px"> perda de carga é a dissipação de energia que um líquido sofre ao escoar por uma tubulação, causada pelo atrito do fluido com as paredes internas do tubo e pela turbulência gerada em conexões. Essa perda de energia resulta em uma queda de pressão ao longo do encanamento.</span>

# %% [markdown]
# <img src="imag.1.png" alt="Tela do instalador Python no Windows" width="1150" style="display: block; margin: 0 auto;">

# %% [markdown]
# ## Medidores Diretos:

# %% [markdown]
# ### 1. Medidor de Fluxo por Área Variável
#
# <span style="font-size:22px">São medidores em que a área de escoamento muda automaticamente em função da vazão do fluido. À medida que o fluxo aumenta, um elemento móvel (normalmente um flutuador) desloca-se, aumentando a área de passagem e estabelecendo um novo equilíbrio. A posição desse elemento móvel é então utilizada para indicar a vazão.</span>

# %% [markdown]
# ### Rotâmetro

# %% [markdown]
# <img src="imag.2.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# #### Princípio de Funcionamento
#
# #### O princípio baseia-se no equilíbrio entre três forças:
# <span style="font-size:22px">1. Peso do flutuador\
# 2. Empuxo exercido pelo fluido\
# 3. Força de arraste causada pelo escoamento</span>
#
# #### Quando o fluido entra pelo fundo do medidor:
#
# <span style="font-size:22px">O fluido empurra o flutuador para cima e o flutuador sobe até que as forças se equilibrem, quanto maior a vazão, maior será a altura atingida pelo flutuador.
# A posição do flutuador é convertida em uma leitura de vazão.</span>

# %% [markdown]
# ### Vantagens
#
# <span style="font-size:22px">Simplicidade - Não necessita de alimentação elétrica para operação básica.\
# Baixa perda de carga - A obstrução ao escoamento é pequena.\
# Fácil instalação - Pode ser instalado sem circuitos eletrônicos complexos.\
# Baixo custo - Especialmente em comparação com medidores eletromagnéticos ou ultrassônicos.\
# Leitura direta - A vazão pode ser observada visualmente.\
# Boa confiabilidade - Possui poucas partes móveis.</span>
#
# ### Desvantagens
# <span style="font-size:22px">Instalação obrigatoriamente vertical - O funcionamento depende da ação da gravidade.\
# Sensível à densidade e viscosidade - Mudanças nas propriedades do fluido afetam a calibração.\
# Precisão moderada - Normalmente entre ±1% e ±5% do fundo de escala.\
# Limitado para altas pressões e temperaturas - Dependendo do material construtivo.\
# Dificuldade para fluidos sujos - Partículas podem travar o flutuador.</span>

# %% [markdown]
# ### Faixas Típicas de Medição
# #### Líquidos:
# <span style="font-size:22px">Alguns mL/min\
# Até milhares de L/min</span>
#
# #### Gases:
# <span style="font-size:22px">Alguns cm³/min\
# Até centenas de m³/h</span>

# %% [markdown]
# ### Precisão:
#
# <span style="font-size:22px">Tipicamente de ±1% à ±5%\
# dependendo do modelo e da aplicação.</span>

# %% [markdown]
# ### Aplicações do Rotâmetro:
# #### Laboratórios:
# <span style="font-size:22px">Bancadas didáticas\
# Ensaios experimentais</span>
#
# #### Indústria Química:
# <span style="font-size:22px">Controle de reagentes\
# Dosagem de produtos</span>

# %% [markdown]
# #### Preços (Brasil)
#
# | Tipo de Rotâmetro                  | Faixa de Preço        |
# | ---------------------------------- | --------------------- |
# | Acrílico simples                   | R$ 80 – R$ 300        |
# | Laboratorial em vidro              | R$ 150 – R$ 800       |
# | Industrial em inox                 | R$ 1.000 – R$ 8.000   |
# | Industrial com transmissor 4–20 mA | R$ 3.000 – R$ 15.000+ |

# %% [markdown]
# ### Exemplar:
# Disponível em: https://www.mercadolivre.com.br/rotametro-fluxometro-medidor-vazao-ar--gas-01-a-15---lpm/up/MLBU1458450915?matt_tool=18956390&utm_source=google_shopping&utm_medium=organic&pdp_filters=item_id%3AMLB3763139667&from=gshop

# %% [markdown]
# <img src="Exemp1.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# <img src="Exemp2.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### 2. Medidores Térmicos de Fluxo de Massa
#
# <span style="font-size:22px">Os medidores térmicos de fluxo de massa são instrumentos que medem diretamente a vazão mássica de um fluido utilizando os efeitos da transferência de calor entre um elemento aquecido e o fluido em movimento. São especialmente utilizados para medição de gases, onde oferecem alta precisão e ampla faixa de medição.</span>

# %% [markdown]
# <img src="imag.3.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# #### Princípio de Funcionamento:
# #### O funcionamento baseia-se no fenômeno da convecção térmica.
# <span style="font-size:22px">Quando um fluido passa por um sensor aquecido
# o sensor transfere calor ao fluido.
# O fluido remove parte dessa energia térmica e
# quanto maior a vazão mássica, maior será a remoção de calor.
# A eletrônica do instrumento relaciona essa perda térmica à vazão de massa.</span>
#
# <span style="font-size:22px">O princípio está associado ao conceito de transferência de calor por convecção.</span>

# %% [markdown]
# ### Métodos de Medição
# #### 1. Potência Constante
#
# <span style="font-size:22px">O sensor é mantido aquecido com potência fixa.\
# O aumento da vazão provoca maior resfriamento.\
# Mede-se a redução da temperatura do sensor.</span>
# #### 2. Temperatura Constante
#
# <span style="font-size:22px">O sensor é mantido em uma temperatura fixa acima da temperatura do fluido.\
# O circuito aumenta ou reduz a potência de aquecimento.\
# A potência necessária para manter a temperatura é proporcional à vazão.</span>
#
# ##### Este é o método mais utilizado industrialmente.

# %% [markdown]
# ### Vantagens:
# <span style="font-size:22px">Medição direta de massa - Não requer conversões de vazão volumétrica para mássica.\
# Excelente para gases - Apresenta alta precisão em ar, nitrogênio, gás natural, biogás e gases industriais.\
# Sem partes móveis - Reduz desgaste mecânico e necessidade de manutenção.\
# Baixa perda de carga - Provoca pouca interferência no processo.\
# Grande faixa de medição (Turndown) - Relações típicas: 50:1, 100:1, até 1000:1 em modelos avançados\
# Boa sensibilidade para baixas vazões - Consegue detectar fluxos muito pequenos com precisão.</span>
# ### Desvantagens
# <span style="font-size:22px">Dependência das propriedades térmicas - Mudanças na composição do fluido afetam a calibração.\
# Menos indicado para líquidos - O desempenho é superior em gases.\
# Sensibilidade a contaminantes - Sujeira depositada nos sensores altera a transferência de calor.\
# Tempo de resposta moderado - Pode ser mais lento que medidores ultrassônicos ou Coriolis.\
# Necessidade de calibração específica - Normalmente calibrado para um gás determinado.</span>

# %% [markdown]
# | Característica   | Valor Típico                    |
# | ---------------- | ------------------------------- |
# | Variável medida  | Vazão mássica                   |
# | Fluido principal | Gases                           |
# | Precisão         | ±0,5% a ±2%                     |
# | Faixa de medição | Muito ampla                     |
# | Partes móveis    | Não                             |
# | Perda de carga   | Muito baixa                     |
# | Saída            | 4–20 mA, HART, Modbus, Profibus |

# %% [markdown]
# ### Aplicações
# #### Indústria Química
# <span style="font-size:22px">Controle de gases de processo\
# Dosagem de reagentes gasosos</span>
# #### Petróleo e Gás
# <span style="font-size:22px">Gás natural\
# Biogás</span>
# #### Sistemas HVAC
# <span style="font-size:22px">Controle de ventilação\
# Monitoramento de ar condicionado industrial</span>

# %% [markdown]
# | Tipo                                | Faixa de Preço          |
# | ----------------------------------- | ----------------------- |
# | Inserção para ar comprimido         | R$ 4.000 – R$ 12.000    |
# | Industrial padrão                   | R$ 8.000 – R$ 25.000    |
# | Com comunicação digital avançada    | R$ 15.000 – R$ 50.000   |
# | Modelos para gás natural e custódia | R$ 30.000 – R$ 100.000+ |

# %% [markdown]
# ### Exemplar:
# Disponível em: https://pt.aliexpress.com/item/1005010196277246.html?src=google#nav-specification

# %% [markdown]
# <img src="Exemp3.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# <img src="Exemp4.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### 3. Medidores de Fluxo por Efeito Coriolis
#
# <span style="font-size:22px">Os medidores de fluxo por efeito Coriolis estão entre os instrumentos de medição de vazão mais precisos disponíveis atualmente. Eles medem diretamente a vazão mássica de líquidos, gases e até fluidos multifásicos, utilizando as forças inerciais geradas pelo movimento do fluido em tubos vibratórios.</span>
#
# <span style="font-size:22px">Diferentemente dos medidores volumétricos, que medem volume e posteriormente convertem para massa, o Coriolis mede diretamente a vazão mássica, independentemente de variações de temperatura, pressão ou densidade.</span>

# %% [markdown]
# <img src="imag.7.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Conceito Básico
#
# ##### O medidor possui um ou mais tubos metálicos que são mantidos vibrando por um excitador eletromagnético.
#
# #### Sem escoamento:
#
# <span style="font-size:22px">Os tubos vibram de forma simétrica.</span>
#
# #### Com escoamento:
#
# <span style="font-size:22px">O fluido que entra e sai dos tubos sofre acelerações e desacelerações gerando forças de Coriolis e essas forças provocam uma torção nos tubos.</span>
#
# ##### Quanto maior a vazão mássica maior a torção e maior a diferença de fase detectada pelos sensores.
#
# <span style="font-size:22px">Essa diferença é diretamente proporcional à vazão mássica.</span>

# %% [markdown]
# ### Equação Fundamental
#
# #### A força de Coriolis pode ser expressa por:
#
# $\LARGE F_c = 2m(v \times w)$
#
# #### Onde:
#
# $\large F_c$<span style="font-size:22px"> = força de Coriolis\
# m = massa\
# v = velocidade do fluido\
# ω = velocidade angular da vibração</span>
#
# <span style="font-size:22px">Na prática, o instrumento mede o deslocamento e a defasagem dos tubos, convertendo-os diretamente em vazão mássica.</span>

# %% [markdown]
# ### Vantagens
# <span style="font-size:22px">Medição direta de massa - Não necessita compensação de pressão ou temperatura.\
# Altíssima precisão - Precisões típicas: ±0,05%/±0,1%/±0,2%\
# Mede líquidos e gases - Funciona em praticamente qualquer fluido.\
# Mede densidade simultaneamente - A frequência natural dos tubos varia conforme a densidade do fluido.\
# Sem necessidade de trechos retos - Pode ser instalado próximo a curvas e válvulas.\
# Baixa necessidade de manutenção - Não possui partes móveis em contato mecânico.\
# Excelente repetibilidade - Uma das melhores entre todos os medidores industriais.</span>
#
# ### Desvantagens
# <span style="font-size:22px">Alto custo - É um dos medidores mais caros do mercado.\
# Peso elevado - Especialmente em grandes diâmetros.\
# Sensível a vibrações externas - Pode exigir suportação adequada.\
# Limitação em grandes tubulações - Acima de determinados diâmetros o custo torna-se muito elevado.\
# Perda de carga moderada - Maior que em medidores ultrassônicos.</span>

# %% [markdown]
# ### Aplicações
# #### Indústria Petroquímica
# <span style="font-size:22px">Combustíveis\
# Óleos\
# Derivados de petróleo</span>
# #### Transferência Fiscal (Custody Transfer)
# <span style="font-size:22px">Medição comercial de: Diesel, Gasolina, Querosene e Etanol</span>
# #### Indústria Química
# <span style="font-size:22px">Dosagem precisa de reagentes\
# Controle de processos</span>

# %% [markdown]
# | Tipo                        | Faixa de Preço           |
# | --------------------------- | ------------------------ |
# | Pequeno porte (laboratório) | R$ 8.000 – R$ 25.000     |
# | Industrial padrão           | R$ 20.000 – R$ 80.000    |
# | Alta precisão               | R$ 50.000 – R$ 200.000   |
# | Transferência fiscal        | R$ 100.000 – R$ 500.000+ |

# %% [markdown]
# ### Exemplar:
# Disponíveç em: https://loja.gatinstrumentacaoindustrial.com/produtos/medidor-de-vazao-massico-coriolis-promass-endress-hauser/?variant=935348875&pf=mc&srsltid=AfmBOor59g8WK_YErikSxJUDtd4kHBvgvDyOqs7Q1BtXY7dRSXPF5DFjTT0

# %% [markdown]
# <img src="Exemp5.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# <img src="Exemp6.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### 4. Medidores de Fluxo Mecânicos (Deslocamento Positivo)
#
# <span style="font-size:22px">Os medidores de fluxo por deslocamento positivo (PD – Positive Displacement Flow Meters) são instrumentos que medem a vazão através da divisão do fluido em volumes conhecidos e sucessivos. Cada volume deslocado corresponde a uma quantidade fixa de fluido, permitindo a medição direta do volume total que passou pelo medidor.</span>
#
# <span style="font-size:22px">À medida que esses volumes se enchem e esvaziam, ocorre o deslocamento de componentes mecânicos (engrenagens, pistões, discos, lóbulos etc.), cujo movimento é contado e convertido em vazão ou volume acumulado.</span>

# %% [markdown]
# <img src="imag.10.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Princípio de Funcionamento
#
# #### O princípio baseia-se na contagem de volumes conhecidos.
#
# <span style="font-size:22px">1. O fluido entra no medidor.\
# 2. Uma câmara interna é preenchida.\
# 3. O fluido desloca um elemento mecânico.\
# 4. O volume aprisionado é descarregado.\
# 5. O ciclo se repete continuamente.\
# 6. O número de ciclos é proporcional ao volume total escoado.</span>

# %% [markdown]
# ### Vantagens
# <span style="font-size:22px">Alta precisão - Precisões típicas entre: ±0,1% e ±0,5%\
# Excelente repetibilidade - Muito utilizada para faturamento e transferência comercial.\
# Boa medição em baixas vazões - Mantém boa precisão mesmo com escoamentos reduzidos.\
# Independência do perfil de velocidade - Não necessita trechos retos longos.\
# Funciona bem com fluidos viscosos - Óleos e combustíveis geralmente melhoram o desempenho.\
# Medição direta do volume - Não depende de cálculos complexos.</span>
#
# ### Desvantagens
# <span style="font-size:22px">Possui partes móveis - Maior desgaste mecânico.\
# Maior necessidade de manutenção - Comparado a medidores ultrassônicos ou eletromagnéticos.\
# Sensível a partículas sólidas - Impurezas podem causar travamentos.\
# Perda de carga relativamente alta - Devido às câmaras internas.\
# Menos indicado para fluidos abrasivos - Pode ocorrer desgaste acelerado.</span>

# %% [markdown]
# ### 4.1. Medidor de Engrenagens Ovais:
# ### Funcionamento
#
# <span style="font-size:22px">Possui duas engrenagens ovais sincronizadas que giram dentro de uma câmara. Cada rotação desloca um volume fixo de fluido.</span>

# %% [markdown]
# <img src="imag.10.3.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Características
# <span style="font-size:22px">Alta precisão.\
# Excelente para líquidos viscosos.\
# Construção robusta.\
# Muito utilizado em combustíveis e óleos.</span>

# %% [markdown]
# ### Aplicações
# <span style="font-size:22px">Óleo lubrificante\
# Diesel\
# Combustíveis\
# Tintas\
# Produtos químicos viscosos</span>

# %% [markdown]
# ### Precisão
#
# #### Tipicamente: ±0.2% à ±0.5%

# %% [markdown]
# ### 4.2. Medidor de Pistão Oscilante
# #### Funcionamento:
#
# <span style="font-size:22px">Um pistão move-se dentro de uma câmara circular. Cada oscilação desloca um volume fixo de fluido.</span>

# %% [markdown]
# <img src="imag.10.2.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Características
# <span style="font-size:22px">Muito utilizado em medição de água.\
# Boa precisão.\
# Construção relativamente simples.</span>

# %% [markdown]
# ### Aplicações
# <span style="font-size:22px">Hidrômetros residenciais\
# Sistemas prediais\
# Água potável</span>

# %% [markdown]
# ### Precisão
#
# #### Tipicamente: ±1% à ±2%

# %% [markdown]
# ### 4.3. Medidor de Disco Nutante (Nutating Disc)
# #### Funcionamento:
#
# <span style="font-size:22px">Possui um disco inclinado que realiza um movimento de nutação (semelhante ao movimento de uma moeda girando sobre uma mesa). Cada ciclo desloca um volume conhecido.</span>

# %% [markdown]
# <img src="imag.10.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Características
# <span style="font-size:22px">Muito utilizado em pequenos medidores.\
# Boa precisão em baixas vazões.\
# Baixo custo de fabricação.</span>

# %% [markdown]
# ### Aplicações
# <span style="font-size:22px">Hidrômetros\
# Sistemas domésticos\
# Distribuição de água</span>

# %% [markdown]
# ### Precisão
#
# #### Tipicamente: ±1% à ±2%

# %% [markdown]
# | Tipo                                 | Faixa de Preço          |
# | ------------------------------------ | ----------------------- |
# | Disco Nutante residencial            | R$ 100 – R$ 800         |
# | Pistão Oscilante industrial          | R$ 500 – R$ 5.000       |
# | Engrenagens Ovais industriais        | R$ 2.000 – R$ 30.000    |
# | Transferência fiscal de combustíveis | R$ 10.000 – R$ 100.000+ |

# %% [markdown]
# ### Exemplares:
# Disponível em: https://simpsonfarmparts.com/pt-br/products/sotera-poly-digital-chemical-transfer-nutating-disc-flow-meter-1-fnpt-2-20-gpm-825?variant=47843716333787&country=BR&currency=BRL&utm_medium=product_sync&utm_source=google&utm_content=sag_organic&utm_campaign=sag_organic&srsltid=AfmBOorxjVZjA_WaC98dgwvLd-0kmcxHInMmnJn5wmxGbZeuXlll7qIiC-0
#
# E em: https://www.mercadolivre.com.br/medidor-de-vazo-eletrnico-de-engrenagem-oval-dn50-de-alta/p/MLB2070817401?matt_tool=18956390&utm_source=google_shopping&utm_medium=organic&pdp_filters=item_id%3AMLB6436565090&from=gshop

# %% [markdown]
# <img src="Exemp7.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# <img src="Exemp8.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# <img src="Exemp9.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# <img src="Exemp10.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ## Medidores Indiretos

# %% [markdown]
# ### 5. Medidores de Fluxo por Pressão Diferencial
#
# <span style="font-size:22px">Os medidores de fluxo por pressão diferencial (ΔP) são os instrumentos de medição de vazão mais utilizados na indústria devido à sua simplicidade, robustez e baixo custo de instalação. Seu funcionamento baseia-se na relação entre a velocidade do fluido e a queda de pressão provocada por uma restrição inserida na tubulação.</span>
#
# <span style="font-size:22px">Diferentemente dos medidores de deslocamento positivo, Coriolis ou térmicos, estes são considerados medidores indiretos, pois não medem a vazão diretamente. Eles medem uma diferença de pressão (ΔP) e utilizam equações para calcular a vazão correspondente.</span>

# %% [markdown]
# ### Funcionamento
#
# <span style="font-size:22px">São dispositivos que provocam uma redução controlada da área de escoamento do fluido. Quando o fluido atravessa essa restrição: A velocidade aumenta, a pressão estática diminui e Surge uma diferença de pressão entre montante e jusante.</span>
#
# <span style="font-size:22px">Essa diferença de pressão é medida e convertida em vazão.</span>

# %% [markdown]
# ### Relação Fundamental
#
# #### A vazão é calculada por: $Q =K\sqrt{ΔP}$
# 	​
# #### Onde:
#
# <span style="font-size:22px">Q = vazão\
# K = constante do medidor\
# ΔP = pressão diferencial</span>
#
# ##### Essa relação mostra que a vazão é proporcional à raiz quadrada da pressão diferencial medida.

# %% [markdown]
# ### Elementos Secundários
#
# #### Responsável por medir o ΔP.
#
# ##### Normalmente utiliza-se um: Transmissor de pressão diferencial (DP Transmitter)
# ### Elementos de Compensação (quando necessário)
#
# ##### Para gases e vapor pode ser necessário medir: Pressão absoluta e Temperatura
#
# ##### A fim de compensar variações de densidade.

# %% [markdown]
# ### Exemplares:

# %% [markdown]
# ### 5.1. Placa de Orifício
#
# ##### A placa de orifício é o elemento primário de pressão diferencial mais utilizado na indústria.

# %% [markdown]
# <img src="imag.4.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Vantagens
# <span style="font-size:22px">Baixo custo.\
# Fácil fabricação.\
# Padronização internacional.\
# Instalação simples.</span>
# ### Desvantagens
# <span style="font-size:22px">Elevada perda permanente de carga.\
# Menor precisão.\
# Sensível ao desgaste do orifício.\
# Necessita trechos retos longos.</span>

# %% [markdown]
# ### Precisão
#
# #### Tipicamente: ±1% à ±2%

# %% [markdown]
# ### Aplicações
# <span style="font-size:22px">Água\
# Vapor\
# Ar comprimido\
# Petróleo\
# Gases industriais</span>

# %% [markdown]
# ### 5.2. Tubo Venturi
#
# ##### O tubo Venturi utiliza uma contração gradual seguida de expansão gradual.
#
# ##### Foi desenvolvido para reduzir perdas de carga.

# %% [markdown]
# <img src="imag.4.2.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Vantagens
# <span style="font-size:22px">Alta precisão.\
# Baixa perda de carga.\
# Excelente para grandes vazões.\
# Boa resistência ao desgaste.</span>
# ### Desvantagens
# <span style="font-size:22px">Custo elevado.\
# Dimensões maiores.\
# Instalação mais complexa.</span>

# %% [markdown]
# ### Precisão
#
# #### Tipicamente: ±0,5% à ±1%

# %% [markdown]
# ### Aplicações
# <span style="font-size:22px">Estações de tratamento de água\
# Sistemas de irrigação\
# Indústria química\
# Grandes tubulações</span>

# %% [markdown]
# ### 5.3. Bocal de Vazão (Flow Nozzle)
#
# #### O bocal de vazão é uma solução intermediária entre a placa de orifício e o Venturi.

# %% [markdown]
# <img src="imag.4.3.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Vantagens
# <span style="font-size:22px">Boa resistência mecânica.\
# Menor desgaste.\
# Adequado para vapor.</span>
# ### Desvantagens
# <span style="font-size:22px">Mais caro que a placa.\
# Perda de carga maior que a do Venturi.</span>

# %% [markdown]
# ### Precisão
#
# #### Tipicamente: ±1%

# %% [markdown]
# ### Aplicações
# <span style="font-size:22px">Vapor superaquecido\
# Altas temperaturas\
# Altas velocidades</span>

# %% [markdown]
# ### 5.4. Tubo de Pitot
#
# #### O tubo de Pitot mede a velocidade local do fluido a partir da diferença entre pressão total e pressão estática.

# %% [markdown]
# <img src="imag.4.4.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Equação da Velocidade
#
# #### A velocidade é determinada por: $v=\sqrt{\frac{2ΔP}{ρ}}$
# #### Onde:
#
# <span style="font-size:22px">v = velocidade\
# ΔP = pressão diferencial\
# ρ = densidade do fluido</span>

# %% [markdown]
# ### Vantagens
# <span style="font-size:22px">Baixíssima perda de carga.\
# Baixo custo.\
# Fácil instalação.</span>
# ### Desvantagens
# <span style="font-size:22px">Mede velocidade local.\
# Menor precisão.\
# Sensível ao alinhamento.</span>

# %% [markdown]
# ### Precisão
#
# #### Tipicamente: ±1% à ±5%

# %% [markdown]
# ### Aplicações
# <span style="font-size:22px">Dutos de ar\
# Sistemas HVAC\
# Chaminés industriais\
# Monitoramento ambiental</span>

# %% [markdown]
# ### Compensação para Gases e Vapor
#
# #### Para gases e vapor, a densidade varia com: Pressão e Temperatura
#
# #### Assim, normalmente são utilizados sensores adicionais:
#
# ##### Transmissor de Pressão: Mede pressão absoluta.
#
# ##### Sensor de Temperatura: Mede temperatura do processo.
#
# ##### Computador de Vazão (Flow Computer)
# ##### Realiza:
#
# <span style="font-size:22px">Correções de densidade\
# Conversão para vazão mássica\
# Totalização</span>

# %% [markdown]
# | Equipamento       | Faixa de Preço       |
# | ----------------- | -------------------- |
# | Placa de Orifício | R$ 200 – R$ 5.000    |
# | Bocal de Vazão    | R$ 1.000 – R$ 10.000 |
# | Tubo Venturi      | R$ 3.000 – R$ 50.000 |
# | Tubo de Pitot     | R$ 100 – R$ 3.000    |
# | Transmissor de ΔP | R$ 1.500 – R$ 20.000 |

# %% [markdown]
# ### 6.Medidores de Fluxo por Eletromagnetismo
#
# <span style="font-size:22px">Os medidores de fluxo eletromagnéticos, também chamados de medidores magnéticos ou magmeters, são instrumentos que medem a vazão de fluidos eletricamente condutivos utilizando a indução eletromagnética..</span>
#
# <span style="font-size:22px">Diferentemente dos medidores por pressão diferencial, eles realizam uma medição direta da velocidade média do fluido, sem criar obstruções significativas ao escoamento.</span>

# %% [markdown]
# <img src="imag.5.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Princípio de Funcionamento
#
# #### Quando um fluido condutivo atravessa um campo magnético:
#
# <span style="font-size:22px">1. O campo magnético é gerado por bobinas instaladas no corpo do medidor.\
# 2. O fluido em movimento corta as linhas do campo magnético.\
# 3. Surge uma tensão elétrica entre dois eletrodos.\
# 4. Essa tensão é proporcional à velocidade do fluido.\
# 5. A velocidade é convertida em vazão.</span>

# %% [markdown]
# ### Lei de Faraday
#
# #### A tensão induzida pode ser expressa por: $E=B⋅L⋅v$
#
# #### Onde:
#
# <span style="font-size:22px">E = tensão induzida (V)\
# B = intensidade do campo magnético (T)\
# L = distância entre os eletrodos (m)\
# v = velocidade média do fluido (m/s)</span>
#
# #### Como B e L são constantes do instrumento:
#
# ### $E∝v$
#
# #### Portanto, a tensão medida é diretamente proporcional à velocidade do fluido.

# %% [markdown]
# ### Vantagens
# <span style="font-size:22px">Sem partes móveis - Reduz desgaste e manutenção.\
# Sem obstruções internas - Praticamente não gera perda de carga adicional.\
# Alta precisão - Precisões típicas: ±0,2% à ±0,5%\
# Excelente para fluidos sujos - Pode medir: Lodo, Polpas minerais, Efluentes\
# Grande faixa de medição - Turndown frequentemente superior a 100:1.\
# Independente da densidade - Mudanças de densidade não afetam significativamente a medição.\
# Independente da viscosidade - Excelente desempenho com fluidos viscosos.</span>
# ### Desvantagens
# <span style="font-size:22px">Requer fluido condutivo - Principal limitação da tecnologia.\
# Não mede gases - Necessita contato elétrico com o fluido.\
# Não mede hidrocarbonetos puros - Combustíveis geralmente possuem baixa condutividade.\
# Custo elevado - Maior que placas de orifício e rotâmetros.\
# Requer alimentação elétrica - Não funciona de forma puramente mecânica.</span>

# %% [markdown]
# ### Precisão: ±0,2% a ±0,5%

# %% [markdown]
# ### Aplicações
# #### Saneamento
# <span style="font-size:22px">Água tratada\
# Água bruta\
# Esgoto\
# Estações de tratamento</span>
# #### Mineração
# <span style="font-size:22px">Polpas minerais\
# Rejeitos</span>
# #### Indústria Química
# <span style="font-size:22px">Ácidos\
# Bases\
# Soluções corrosivas</span>

# %% [markdown]
# | Tipo                    | Faixa de Preço         |
# | ----------------------- | ---------------------- |
# | Pequeno porte (½" a 1") | R$ 2.000 – R$ 8.000    |
# | Industrial padrão       | R$ 5.000 – R$ 30.000   |
# | Grandes diâmetros       | R$ 20.000 – R$ 150.000 |
# | Sanitário/farmacêutico  | R$ 15.000 – R$ 80.000  |

# %% [markdown]
# ### Exemplar:
# Disponível em: https://www.mercadolivre.com.br/medidor-vazo-fluxo-eletromagnetico-dn100-100mm-4-polegadas/p/MLB27531606?matt_tool=18956390&utm_source=google_shopping&utm_medium=organic&pdp_filters=item_id:MLB3577821043

# %% [markdown]
# <img src="Exemp11.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# <img src="Exemp12.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### 7.Medidores de Fluxo Ultrassônicos
#
# <span style="font-size:22px">Os medidores de fluxo ultrassônicos utilizam ondas sonoras de alta frequência (ultrassom) para determinar a velocidade e a vazão de um fluido.</span>

# %% [markdown]
# ### Princípio de Funcionamento
#
# #### Os medidores ultrassônicos operam analisando o comportamento das ondas sonoras propagadas através do fluido.
#
# #### Existem dois métodos principais:
#
# <span style="font-size:22px">Tempo de Trânsito (Transit Time)\
# Efeito Doppler</span>

# %% [markdown]
# ### 7.1. Medidor Ultrassônico por Tempo de Trânsito
#
# #### É o método mais utilizado em líquidos limpos.
#
# ### Funcionamento
#
# #### Dois transdutores são instalados em lados opostos da tubulação.
#
# #### Um sinal é enviado:
#
# <span style="font-size:22px">No sentido do fluxo.\
# Contra o sentido do fluxo.</span>
#
# #### A velocidade do som é afetada pelo movimento do fluido.
#
# #### Consequentemente:
#
# <span style="font-size:22px">O tempo de propagação a favor do fluxo diminui.\
# O tempo de propagação contra o fluxo aumenta.</span>
#
# #### A diferença entre esses tempos permite calcular a velocidade do fluido.

# %% [markdown]
# <img src="imag.6.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Vantagens
# <span style="font-size:22px">Alta precisão.\
# Sem perda de carga.\
# Excelente para líquidos limpos.\
# Não possui partes móveis.</span>
# ### Desvantagens
# <span style="font-size:22px">Sensível à presença de bolhas.\
# Exige fluido relativamente homogêneo.\
# Custo elevado.</span>

# %% [markdown]
# ### 7.2. Medidor Ultrassônico por Efeito Doppler
#
# #### Utilizado quando o fluido contém partículas sólidas ou bolhas em suspensão.
#
# ### Funcionamento
#
# #### O transdutor emite uma onda ultrassônica. Essa onda é refletida pelas partículas ou bolhas presentes no fluido e o sinal refletido retorna com uma frequência diferente devido ao efeito Doppler.
#
# #### A variação de frequência é utilizada para calcular a velocidade do escoamento.

# %% [markdown]
# <img src="imag.6.2.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Equação Conceitual
#
# #### A frequência Doppler pode ser expressa por:
#
# #### Δf∝v
#
# #### Onde:
#
# <span style="font-size:22px">Δf = variação de frequência\
# v = velocidade do fluido</span>

# %% [markdown]
# ### Vantagens
# <span style="font-size:22px">Funciona com líquidos sujos.\
# Adequado para lodos e efluentes.\
# Instalação simples.</span>
# ### Desvantagens
# <span style="font-size:22px">Menor precisão.\
# Requer partículas ou bolhas para funcionar.</span>

# %% [markdown]
# ### Tipos de Instalação
# ### Clamp-On
#
# #### Os sensores são fixados externamente à tubulação.
#
# ### Vantagens
# <span style="font-size:22px">Não exige corte da tubulação.\
# Instalação rápida.\
# Sem contato com o fluido.</span>
# ### Aplicações
# <span style="font-size:22px">Sistemas temporários.\
# Auditorias energéticas.\
# Testes de campo.</span>
#
# ### In-Line
#
# #### Os transdutores ficam em contato direto com o fluido.
#
# ### Vantagens
# <span style="font-size:22px">Maior precisão.\
# Menor influência externa.</span>
# ### Aplicações
# <span style="font-size:22px">Processos industriais permanentes.</span>

# %% [markdown]
# ### Sensores Necessários
#
# #### Os medidores ultrassônicos normalmente utilizam:
#
# #### Transdutores Ultrassônicos - Emissão e recepção das ondas sonoras.
#
# #### Conversor Eletrônico - Processamento dos sinais.

# %% [markdown]
# ### Vantagens
# <span style="font-size:22px">Sem partes móveis - Praticamente elimina desgaste mecânico.\
# Sem perda de carga - Não cria obstruções no escoamento.\
# Alta precisão - Especialmente em modelos por tempo de trânsito.\
# Instalação externa possível - Tecnologia Clamp-On.\
# Baixa manutenção - Longa vida útil.\
# Aplicável a grandes diâmetros - Muito utilizado em adutoras e oleodutos.</span>
# ### Desvantagens
# <span style="font-size:22px">Custo elevado - Superior ao de placas de orifício e rotâmetros.\
# Sensível à qualidade do sinal - Bolhas e turbulências podem afetar a medição.\
# Exige perfil de escoamento adequado - Normalmente necessita trechos retos.\
# Instalação mais complexa - Alinhamento correto dos sensores é fundamental.</span>

# %% [markdown]
# ### Precisão (Transit Time)	±0,5% a ±1%
# ### Precisão (Doppler)	±1% a ±5%

# %% [markdown]
# ### Aplicações
# #### Saneamento
# <span style="font-size:22px">Água tratada\
# Água bruta\
# Adutoras</span>
# #### Petróleo e Gás
# <span style="font-size:22px">Oleodutos\
# Gasodutos\
# Transferência de produtos</span>
# #### Energia
# <span style="font-size:22px">Circuitos de refrigeração\
# Usinas hidrelétricas\
# Sistemas térmicos</span>

# %% [markdown]
# | Tipo                                 | Faixa de Preço          |
# | ------------------------------------ | ----------------------- |
# | Clamp-On portátil                    | R$ 5.000 – R$ 30.000    |
# | Clamp-On industrial                  | R$ 10.000 – R$ 80.000   |
# | In-Line industrial                   | R$ 8.000 – R$ 100.000   |
# | Custody Transfer para petróleo e gás | R$ 50.000 – R$ 500.000+ |

# %% [markdown]
# ### Exemplares:
# Disponível em: https://www.fertronshop.com.br/automacao/medidor-de-vazao-ultrassonico-ufm-2000sw-fertron/?variant_id=479
#
# E em: https://www.ato.com/doppler-ultrasonic-flow-meter?srsltid=AfmBOoqew9huuolAJHqKDxWKf96f_D7q7eelVMIN4C2Ve5SPUl_PmjqE_rs

# %% [markdown]
# <img src="Exemp13.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# <img src="Exemp14.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">
# <img src="Exemp15.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# <img src="Exemp16.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# <img src="Exemp17.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### 8.Medidores de Fluxo por Força de Arrasto
#
# <span style="font-size:22px">Os medidores de fluxo por força de arrasto (Drag Force Flow Meters) medem a vazão de um fluido a partir da força exercida pelo escoamento sobre um corpo fixo inserido na tubulação. Essa força, denominada força de arrasto, é proporcional à velocidade do fluido e pode ser convertida em vazão volumétrica ou mássica.</span>

# %% [markdown]
# <img src="imag.8.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Princípio de Funcionamento
#
# #### O funcionamento baseia-se na força de arrasto gerada pelo escoamento sobre um obstáculo.
#
# #### Quanto maior a velocidade do fluido:
#
# <span style="font-size:22px">Maior a força exercida.\
# Maior a deformação do sensor.\
# Maior o sinal gerado.</span>

# %% [markdown]
# ### Força de Arrasto
#
# #### A força de arrasto pode ser expressa por:
#
# $\large F_d = \frac{1}{2}C_dρAv^2$
#
# #### Onde:
#
# $\large F_d$<span style="font-size:22px"> = força de arrasto (N)</span>\
# $\large C_d$<span style="font-size:22px"> = coeficiente de arrasto</span>\
# <span style="font-size:22px">ρ = densidade do fluido (kg/m³)\
# A = área projetada do sensor (m²)\
# v = velocidade do fluido (m/s)</span>
#
# #### Observa-se que a força é proporcional ao quadrado da velocidade.

# %% [markdown]
# ### Vantagens
# <span style="font-size:22px">Construção simples - Possui poucos componentes mecânicos.\
# Aplicável a líquidos, gases e vapor - Grande versatilidade de aplicação.\
# Boa resistência mecânica - Adequado para ambientes industriais severos.\
# Instalação em grandes diâmetros - Particularmente vantajoso em tubulações extensas.\
# Baixa manutenção - Não possui partes móveis rotativas.\
# Boa faixa de medição - Turndown típico: 10:1, 20:1</span>
# ### Desvantagens
# <span style="font-size:22px">Necessita conhecimento da densidade - Como a força depende da densidade do fluido.\
# Sensível ao perfil de escoamento - Curvas, válvulas e turbulências podem afetar a precisão.\
# Introduz obstrução ao fluxo - O elemento sensor permanece dentro da tubulação.\
# Influência de vibrações mecânicas - Tubulações vibrando podem gerar erros.</span>

# %% [markdown]
# ### Precisão
# #### Na faixa de: ±1% à ±3%

# %% [markdown]
# ### Aplicações
# #### Vapor Industrial
#
# <span style="font-size:22px">Caldeiras\
# Redes de distribuição\
# Processos térmicos</span>
# #### Ar Comprimido
# <span style="font-size:22px">Linhas industriais\
# Sistemas pneumáticos</span>
# #### Gases Industriais
# <span style="font-size:22px">Nitrogênio\
# Oxigênio\
# Hidrogênio\
# Gás natural</span>

# %% [markdown]
# ### Sensores Adicionais
#
# #### Dependendo da aplicação, podem ser utilizados:
#
# #### Sensor de Temperatura - Necessário para compensação de gases e vapor.
#
# #### Sensor de Pressão - Utilizado para determinar a densidade do fluido.

# %% [markdown]
# | Tipo                                     | Faixa de Preço        |
# | ---------------------------------------- | --------------------- |
# | Inserção simples                         | R$ 2.000 – R$ 8.000   |
# | Industrial padrão                        | R$ 5.000 – R$ 20.000  |
# | Com compensação de pressão e temperatura | R$ 10.000 – R$ 40.000 |
# | Aplicações especiais para vapor          | R$ 15.000 – R$ 60.000 |

# %% [markdown]
# ### 9. Medidores de Fluxo por Vórtice
#
# <span style="font-size:22px">Os medidores de fluxo por vórtice (Vortex Flow Meters) são instrumentos que medem a vazão a partir da formação periódica de vórtices gerados quando um fluido escoa ao redor de um obstáculo inserido na tubulação.</span>

# %% [markdown]
# <img src="imag.9.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ### Princípio de Funcionamento
#
# #### O medidor possui um obstáculo fixo instalado no interior da tubulação.
#
# #### À medida que o fluido passa:
#
# <span style="font-size:22px">1. O fluxo encontra o obstáculo.\
# 2. Formam-se vórtices alternadamente à esquerda e à direita.\
# 3. Surge uma oscilação periódica de pressão.\
# 4. Um sensor detecta essa oscilação.\
# 5. A frequência medida é utilizada para determinar a velocidade do escoamento.</span>

# %% [markdown]
# ### Rua de Von Kármán
#
# #### O fenômeno foi estudado por Theodore von Kármán e descreve a formação alternada de vórtices atrás de um obstáculo submetido a um fluxo.
#
# #### A frequência dos vórtices é relacionada à velocidade do fluido pelo Número de Strouhal.

# %% [markdown]
# ### Equação Fundamental
#
# #### A relação básica é:
#
# $\large f=St⋅\frac{v}{d}$
# 	​
#
#
# #### Onde:
#
# <span style="font-size:22px">f = frequência dos vórtices (Hz)\
# St = número de Strouhal\
# v = velocidade do fluido (m/s)\
# d = largura do obstáculo (m)</span>
#
# #### Como St e d são constantes do medidor:
#
# #### f∝v
#
# #### Logo, a frequência é diretamente proporcional à velocidade do fluido.

# %% [markdown]
# ### Sensores Adicionais
#
# #### Sensor de Temperatura - Determina a temperatura do fluido.
#
# #### Sensor de Pressão - Permite calcular a densidade.

# %% [markdown]
# ### Vantagens
# <span style="font-size:22px">Sem partes móveis - Reduz manutenção e desgaste.\
# Boa precisão - Precisões típicas: ±0,5% à ±1%\
# Funciona com líquidos, gases e vapor - Grande versatilidade.\
# Excelente para vapor - Uma das tecnologias mais utilizadas para medição de vapor industrial.\
# Boa resistência a altas temperaturas - Alguns modelos operam acima de 400 °C.\
# Baixa manutenção - Longa vida útil.</span>
# ### Desvantagens
# <span style="font-size:22px">Sensível a vibrações externas - Vibrações da tubulação podem interferir na medição.\
# Necessita velocidade mínima - Abaixo de determinada velocidade não ocorre formação estável de vórtices.\
# Não indicado para fluidos muito viscosos - A viscosidade elevada prejudica a formação dos vórtices.\
# Exige trechos retos - Normalmente requer: 10 a 30 diâmetros a montante e 5 a 10 diâmetros a jusante\
# Pode gerar pequena perda de carga - Devido ao obstáculo inserido.</span>

# %% [markdown]
# ### Precisão: ±0,5% a ±1%

# %% [markdown]
# ### Aplicações
# #### Indústria Química
# <span style="font-size:22px">Solventes\
# Produtos químicos</span>
# #### Energia
# <span style="font-size:22px">Sistemas térmicos\
# Centrais de geração</span>
# #### Petróleo e Gás
# <span style="font-size:22px">Linhas de utilidades\
# Sistemas auxiliares</span>

# %% [markdown]
# | Tipo                                     | Faixa de Preço        |
# | ---------------------------------------- | --------------------- |
# | Pequeno porte                            | R$ 3.000 – R$ 10.000  |
# | Industrial padrão                        | R$ 5.000 – R$ 30.000  |
# | Com compensação de pressão e temperatura | R$ 10.000 – R$ 50.000 |
# | Vapor de alta temperatura                | R$ 20.000 – R$ 80.000 |

# %% [markdown]
# ### Exemplar:
# Disponível em: https://www.fertronshop.com.br/medidores/medidor-de-vazao-vortex-vfm-tamanho-1-fertron/

# %% [markdown]
# <img src="Exemp18.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# <img src="Exemp19.png" alt="Tela do instalador Python no Windows" width="800" style="display: block; margin: 0 auto;">

# %% [markdown]
# ## Calibração de Medidores de Vazão:

# %% [markdown]
# <span style="font-size:22px">A calibração de medidores de vazão é o processo de comparação das indicações fornecidas pelo instrumento com um padrão de referência rastreável, visando determinar e corrigir erros de medição. Esse procedimento garante que as medições de vazão permaneçam confiáveis, atendendo requisitos de qualidade, segurança operacional e conformidade normativa.</span>

# %% [markdown]
# ### Objetivos da Calibração
# <span style="font-size:22px">1. Verificar a exatidão do instrumento.\
# 2. Determinar erros sistemáticos e aleatórios.\
# 3. Ajustar ou corrigir o medidor quando necessário.\
# 4. Garantir rastreabilidade metrológica.\
# 5. Atender normas técnicas e requisitos regulatórios.</span>

# %% [markdown]
# ### Métodos de Calibração
# ### Método Gravimétrico
#
# #### Considerado um dos métodos mais precisos.
#
# #### Princípio:
#
# <span style="font-size:22px">O fluido é coletado em um reservatório.\
# Mede-se a massa acumulada.\
# A vazão é calculada a partir da massa e do tempo.</span>
#
# ### Vantagens:
#
# <span style="font-size:22px">Alta precisão.\
# Baixa incerteza.</span>
#
# ### Aplicação:
#
# <span style="font-size:22px">Laboratórios de calibração primária.</span>
# ### Método Volumétrico
#
# #### Princípio:
#
# <span style="font-size:22px">Mede-se diretamente o volume acumulado durante um intervalo de tempo.</span>
#
# ### Vantagens:
#
# <span style="font-size:22px">Simplicidade.\
# Boa precisão.</span>
#
# ### Aplicação:
#
# <span style="font-size:22px">Bancadas industriais de calibração.</span>
# ### Comparação com Medidor Padrão
#
# #### Princípio:
#
# <span style="font-size:22px">O medidor sob teste é instalado em série com um medidor padrão calibrado.</span>
#
# ### Vantagens:
#
# <span style="font-size:22px">Processo rápido.\
# Pode ser realizado em campo.</span>
#
# ### Aplicação:
#
# <span style="font-size:22px">Calibração operacional e verificações periódicas.</span>

# %% [markdown]
# ### Medidores Utilizados como Padrão
#
# #### Os padrões devem possuir incerteza significativamente menor que a do instrumento sob calibração.
#
# ### Medidor Coriolis
#
# ### Vantagens:
#
# <span style="font-size:22px">Mede diretamente vazão mássica.\
# Alta exatidão.\
# Excelente repetibilidade.</span>
#
# ### Precisão típica: ±0,05% a ±0,10% da leitura.
#
# #### É atualmente um dos melhores padrões secundários disponíveis.
#
# ### Sistema Gravimétrico
#
# ### Vantagens:
#
# <span style="font-size:22px">Considerado padrão primário.\
# Menor incerteza disponível.</span>
#
# ### Precisão típica: ±0,01% a ±0,05%.
#
# #### Utilizado em laboratórios acreditados.
#
# ### Medidor Eletromagnético de Referência
#
# ### Vantagens:
#
# <span style="font-size:22px">Boa estabilidade.\
# Adequado para líquidos condutivos.</span>
#
# ### Precisão típica: ±0,2% a ±0,5%.
#
# ### Medidor Ultrassônico de Referência
#
# ### Vantagens:
#
# <span style="font-size:22px">Baixa perda de carga.\
# Instalação relativamente simples.</span>
#
# ### Aplicação:
#
# <span style="font-size:22px">Grandes tubulações e sistemas de água.\
# Curva de Calibração</span>
#
# ### Durante a calibração são obtidos vários pontos ao longo da faixa de medição:
#
# <span style="font-size:22px">10%\
# 25%\
# 50%\
# 75%\
# 100%</span>
#
# ##### da vazão nominal.
#
# #### A partir desses pontos é construída a curva de erro do instrumento.
#
# ### Principais Fontes de Erro
# <span style="font-size:22px">Perfil inadequado de escoamento.\
# Presença de bolhas de ar.\
# Vibrações mecânicas.\
# Variações de temperatura.\
# Variações de pressão.\
# Desgaste mecânico dos componentes.\
# Instalação incorreta.\
# Incerteza de Medição</span>
#
# ### A incerteza da calibração depende de:
#
# <span style="font-size:22px">Instrumento padrão utilizado.\
# Resolução do instrumento.\
# Repetibilidade das leituras.\
# Tempo de medição.\
# Condições ambientais.</span>
#
# #### A avaliação normalmente segue as recomendações da norma: ISO/IEC Guide 98-3 (GUM)

# %% [markdown]
# | Aplicação                 | Intervalo típico     |
# | ------------------------- | -------------------- |
# | Processo industrial comum | 1 ano                |
# | Transferência de custódia | 6 a 12 meses         |
# | Instrumentação crítica    | 6 meses              |
# | Laboratórios              | Conforme acreditação |

# %% [markdown]
# <img src="certificado-de-calibracao.jpg" alt="Tela do instalador Python no Windows" width="900" style="display: block; margin: 0 auto;">

# %%
import math
import random

# =====================================
# MEDIDOR DE VAZÃO TIPO TURBINA
# =====================================

# ---------- Dados mecânicos ----------

diametro_tubo = 0.050      # m (50 mm)
diametro_turbina = 0.045   # m
num_pas = 6

momento_inercia = 2.5e-4   # kg.m²
atrito = 0.015             # atrito mecânico

# ---------- Propriedades do fluido ----------

densidade = 1000.0         # kg/m³
viscosidade = 0.001        # Pa.s

# ---------- Calibração ----------

K_factor = 450.0           # pulsos/L

erro_calibracao = 0.01     # ±1%
erro_eletronico = 0.002    # ±0,2%

# ---------- Estado inicial ----------

vazao_real_m3h = 5.0

rpm_anterior = 0

# =====================================

def calcular_medidor(vazao_m3h):

    global rpm_anterior

    # Conversão
    Q = vazao_m3h / 3600.0

    # Área da tubulação
    area = math.pi * (diametro_tubo**2) / 4

    # Velocidade média do líquido
    velocidade = Q / area

    # Reynolds
    reynolds = (densidade * velocidade * diametro_tubo) / viscosidade

    # Modelo simplificado de turbina

    fator_turbina = 35

    rpm_ideal = fator_turbina * velocidade * 60

    # efeito da inércia

    rpm = rpm_anterior + (rpm_ideal - rpm_anterior) * (
        1.0 / (1.0 + momento_inercia*500)
    )

    rpm *= (1 - atrito)

    rpm_anterior = rpm

    # Frequência gerada

    pulsos_por_segundo = (
        (vazao_m3h * 1000 / 3600)
        * K_factor
    )

    # erros simulados

    erro1 = random.uniform(
        -erro_calibracao,
        erro_calibracao
    )

    erro2 = random.uniform(
        -erro_eletronico,
        erro_eletronico
    )

    erro_total = erro1 + erro2

    vazao_medida = vazao_m3h * (1 + erro_total)

    return {
        "velocidade": velocidade,
        "reynolds": reynolds,
        "rpm": rpm,
        "pps": pulsos_por_segundo,
        "vazao_medida": vazao_medida,
        "erro": erro_total * 100
    }

# =====================================
# LOOP PRINCIPAL
# =====================================

print("\nSIMULADOR DE MEDIDOR DE VAZÃO TIPO TURBINA")
print("------------------------------------------")

while True:

    resultado = calcular_medidor(vazao_real_m3h)

    print("\n===================================")
    print(f"Vazão real       : {vazao_real_m3h:.2f} m³/h")
    print(f"Vazão medida     : {resultado['vazao_medida']:.2f} m³/h")
    print(f"Erro             : {resultado['erro']:.3f} %")
    print("-----------------------------------")
    print(f"Velocidade fluido: {resultado['velocidade']:.3f} m/s")
    print(f"RPM turbina      : {resultado['rpm']:.1f}")
    print(f"Pulsos/s         : {resultado['pps']:.1f}")
    print(f"Reynolds         : {resultado['reynolds']:.0f}")
    print("===================================")

    comando = input(
        "\n[+] aumenta 1 m³/h\n"
        "[-] reduz 1 m³/h\n"
        "[v] definir vazão\n"
        "[q] sair\n"
        "Comando: "
    ).lower()

    if comando == "+":
        vazao_real_m3h += 1

    elif comando == "-":
        vazao_real_m3h = max(0, vazao_real_m3h - 1)

    elif comando == "v":
        try:
            vazao_real_m3h = float(
                input("Nova vazão (m³/h): ")
            )
        except:
            pass

    elif comando == "q":
        break

# %% [markdown]
# ## Referências:
#
# BRUSAMARELLO, V. J.; BALBINOT, A.; “Instrumentação e Fundamentos de Medidas – Vol. 2”;
# LTC
#
# Disponível em: https://www.dwyeromega.com/en-us/resources/variable-area-flow-meter
#
# Disponível em: https://www.professores.uff.br/ninoska/wp-content/uploads/sites/57/2017/08/Aula05_Instrumen_Vazao1sem2016.pdf
